# %% [markdown]
# <a href="https://colab.research.google.com/github/GooZzzEee0123/dumb-goose/blob/master/%E9%85%8D%E8%89%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("SportsAnalytics")
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)
library(ggplot2)

# %%
NBA1819<-fetch_NBAPlayerStatistics("18-19")

# %%
pkgs <- c("tidyverse","lubridate","showtext")
install.packages(pkgs)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(tidyverse)
library(lubridate)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
install.packages("devtools")
devtools::install_github('cttobin/ggthemr')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# ...
# vctrs      (0.3.4 -> 0.3.5) [CRAN]
# magrittr   (1.5   -> 2.0.1) [CRAN]
# rstudioapi (0.12  -> 0.13 ) [CRAN]
# rprojroot  (1.3-2 -> 2.0.2) [CRAN]
# Installing 4 packages: vctrs, magrittr, rstudioapi, rprojroot
#
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ✔  checking for file ‘/tmp/Rtmpz0c4FY/remotes3951b1e500/Mikata-Project-ggthemr-3a86e28/DESCRIPTION’
# ─  preparing ‘ggthemr’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
#    Removed empty directory ‘ggthemr/README_files’
# ─  building ‘ggthemr_1.1.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggthemr)

# %% [markdown]
# **利用order()函數,選一種類型的資料出來,由大到小排序**

# %%
NBA1819Order<-NBA1819[order(NBA1819$FieldGoalsAttempted,decreasing = T),]
NBA1819Order[1:10,]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 206 NBA    James Harden     HOU  PG       78          2870
# 497 NBA    Kemba Walker     CHA  PG       82          2867
# 183 NBA    Paul George      OKL  SF       77          2844
# 40  NBA    Bradley Beal     WAS  SG       82          3025
# 305 NBA    Damian Lillard   POR  PG       80          2836
# 354 NBA    Donovan Mitchell UTA  SG       77          2598
# 434 NBA    D'angelo Russell BRO  PG       81          2446
# 506 NBA    Russel Westbrook OKL  PG       73          2632
# 477 NBA    Klay Thompson    GSW  SG       78          2653
# 150 NBA    Kevin Durant     GSW  SF       78          2703
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 206 843            1909                378        1028            ⋯ 158
# 497 731            1684                260         730            ⋯ 102
# 183 707            1614                292         757            ⋯ 172
# ...

# %% [markdown]
# **用subset()做欄位條件搜尋**

# %%
subset(NBA1819,Team=="UTA")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 10  NBA    Grayson Allen    UTA  SG       37           414
# 64  NBA    Tony Bradley     UTA  C         3            36
# 99  NBA    Tyler Cavanaugh  UTA  PF       11            41
# 121 NBA    Jae Crowder      UTA  PF       80          2167
# 161 NBA    Dante Exum       UTA  PG       42           663
# 163 NBA    Derrick Favors   UTA  PF       76          1770
# 187 NBA    Rudy Gobert      UTA  C        81          2577
# 246 NBA    Joe Ingles       UTA  SF       82          2564
# 288 NBA    Kyle Korver      UTA  SG       70          1332
# 354 NBA    Donovan Mitchell UTA  SG       77          2598
# 355 NBA    Naz Mitrou-long  UTA  SG       14            86
# 374 NBA    Raul Neto        UTA  PG       37           471
# 375 NBA    Georges Niang    UTA  SF       59           517
# 383 NBA    Royce O'neale    UTA  SF       82          1672
# 433 NBA    Ricky Rubio      UTA  PG       68          1904
# ...

# %% [markdown]
# **用grepl()做字串條件搜尋**

# %%
NBA1819[grepl("C",NBA1819$Position),]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 4   NBA    Steven Adams     OKL  C        80          2667
# 5   NBA    Bam Adebayo      MIA  C        82          1908
# 11  NBA    Jarrett Allen    BRO  C        80          2095
# 17  NBA    Ike Anigbogu     IND  C         3             6
# 25  NBA    Deandre Ayton    PHO  C        71          2181
# 31  NBA    Mohamed Bamba    ORL  C        47           765
# 47  NBA    Dairis Bertans   NOR  C        12           167
# 48  NBA    Davis Bertans    SAN  C        76          1634
# 50  NBA    Khem Birch       ORL  C        50           644
# 51  NBA    Bismack Biyombo  CHA  C        54           783
# 58  NBA    Andrew Bogut     GSW  C        11           135
# 64  NBA    Tony Bradley     UTA  C         3            36
# 79  NBA    Thomas Bryant    WAS  C        72          1495
# 89  NBA    Clint Capela     HOU  C        67          2249
# 97  NBA    Wil Cauley-stein SAC  C        81          2216
# ...

# %% [markdown]
# **用ggplot畫出,四種不同類型的圖表**

# %%
NBA1819<-fetch_NBAPlayerStatistics("18-19")
df<-data.frame(gp=NBA1819$TotalMinutesPlayed,y=NBA1819$TotalPoints)

# %% [markdown]
# **散佈圖:**

# %% [markdown]
# 個人犯規與阻攻

# %%
ggthemr("chalk")
qplot(PersonalFouls,Blocks,data=NBA1819)
# Out:
# plot without title

# %% [markdown]
# 上場時長與總得分

# %%
ggthemr("solarized")
ggplot(df,aes(x=gp,y=y))+geom_point()
# Out:
# plot without title

# %% [markdown]
# **長條圖:**

# %% [markdown]
# 犯規數

# %%
ggthemr("sky")
qplot(PersonalFouls,data=NBA1819)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# **折線圖**

# %%
ggthemr("earth")
ggplot(df,aes(NBA1819$TotalMinutesPlayed,NBA1819$TotalPoints,group=1))+geom_line()
# Out:
# plot without title

# %% [markdown]
# **盒狀圖**

# %% [markdown]
# 上場時長與總得分

# %%
ggthemr("sky")
ggplot(df,aes(x=gp,y=y,group=1))+geom_boxplot()
# Out:
# plot without title
